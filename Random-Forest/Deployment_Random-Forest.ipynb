# %%
"""
Deployment 
if input is zero - my weight will become zero and only the bias will be returned as result 
intial level or origin value - bias is very helpful - other names are 
Origin/initial value/bias
"""
import pickle
loaded_model=pickle.load(open("finalized_model_Forest.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])
result
# Out:
# C:\Users\keert\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([47938.381])
